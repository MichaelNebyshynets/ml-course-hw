# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
#import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.ensemble import RandomForestClassifier

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
pd.set_option('display.max_columns', None)
sns.set(font_scale=1.2)

# %% [markdown]
# ЧАСТЬ А

# %%
print("1. Загрузка данных")
df = pd.read_csv('netflix_titles.csv')
print("Первые 5 строк")
df.head()
# Out:
# 1. Загрузка данных
# Первые 5 строк
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
print("Последние 5 строк")
df.tail()
# Out:
# Последние 5 строк
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# 8804   November 1, 2019          2009      R     88 min
# 8805   January 11, 2020          2006     PG     88 min
# 8806      March 2, 2019          2015  TV-14    111 min
#
#                                            listed_in  \
# 8802                  Cult Movies, Dramas, Thrillers
# 8803          Kids' TV, Korean TV Shows, TV Comedies
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             description
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...

# %%
print("Размерность данных")
df.shape
# Out:
# Размерность данных
# (8807, 12)

# %%
print("Информация о датасете(типы данных и количество non-null значений)")
df.info()
# Out:
# Информация о датасете(типы данных и количество non-null значений)
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   str
#  1   type          8807 non-null   str
#  2   title         8807 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7982 non-null   str
#  5   country       7976 non-null   str
#  6   date_added    8797 non-null   str
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   str
#  9   duration      8804 non-null   str
#  10  listed_in     8807 non-null   str
#  11  description   8807 non-null   str
# dtypes: int64(1), str(11)
# memory usage: 825.8 KB

# %%
print("Информация по числовых колонках")
df.describe()
print("Информация по категориальным колонкам")
df.describe(include="object")
# Out:
# Информация по числовых колонках
# Информация по категориальным колонкам
# C:\Users\Лена\AppData\Local\Temp\ipykernel_11876\1098918663.py:4: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# count                                                8807
# unique                                               8775
# top     Paranormal activity at a lush, abandoned prope...
# freq                                                    4

# %%
print("Количество пропущенных значений в каждой колонке")
df.isnull().sum()
# Out:
# Количество пропущенных значений в каждой колонке
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
print("Количество дубликатов строк")
df.duplicated().sum()
# Out:
# Количество дубликатов строк
# np.int64(0)

# %%
print("Типы данных колонок")
df.dtypes
# Out:
# Типы данных колонок
# show_id           str
# type              str
# title             str
# director          str
# cast              str
# country           str
# date_added        str
# release_year    int64
# rating            str
# duration          str
# listed_in         str
# description       str
# dtype: object

# %% [markdown]
# ЧАСТЬ B

# %%
print("Стратегия dropna(удаление строк с пропусками)")
print(f"Размер датасета до удаления: {df.shape}")
df_dropped = df.dropna()
print(f"Размер датасета после удаления: {df_dropped.shape}")
print(f"Удалено строк: {df.shape[0]-df_dropped.shape[0]}")
# Out:
# Стратегия dropna(удаление строк с пропусками)
# Размер датасета до удаления: (8807, 12)
# Размер датасета после удаления: (5332, 12)
# Удалено строк: 3475

# %%
print("Стратегия fillna(заполнение пропусков)")
#создаем копию для заполнения пропусков
df_filled = df.copy()

numeric_cols = df_filled.select_dtypes(include=[np.number]).columns

for col in numeric_cols:
    if df_filled[col].isnull().any():  # проверяем, есть ли пропуски в колонке
        # ОБОСНОВАНИЕ: Используем среднее значение, так как распределение близко к нормальному
        # и нет сильных выбросов, которые могли бы исказить среднее
        mean_val = df_filled[col].mean()
        df_filled[col].fillna(mean_val, inplace=True)
        print(f"Колонка '{col}': заполнена СРЕДНИМ значением {mean_val:.2f}")
        print(f"  Причина: распределение симметричное, нет сильных выбросов")       

# Заполнение категориальных колонок
print("\nЗаполнение категориальных колонок:")
cat_cols = df.select_dtypes(include=['object']).columns

for col in cat_cols:
    if df[col].isnull().any():
        # ОБОСНОВАНИЕ: Для категориальных признаков лучше всего использовать моду,
        # так как это наиболее часто встречающееся значение
        mode_val = df[col].mode()[0]  # mode()[0] берет первое значение моды
        df[col].fillna(mode_val, inplace=True)
        print(f"Колонка '{col}': заполнена МОДОЙ '{mode_val}'")
        print(f"  Причина: мода представляет наиболее типичную категорию")
# Out:
# Стратегия fillna(заполнение пропусков)
#
# Заполнение категориальных колонок:
# Колонка 'director': заполнена МОДОЙ 'Rajiv Chilaka'
#   Причина: мода представляет наиболее типичную категорию
# Колонка 'cast': заполнена МОДОЙ 'David Attenborough'
#   Причина: мода представляет наиболее типичную категорию
# Колонка 'country': заполнена МОДОЙ 'United States'
#   Причина: мода представляет наиболее типичную категорию
# Колонка 'date_added': заполнена МОДОЙ 'January 1, 2020'
#   Причина: мода представляет наиболее типичную категорию
# Колонка 'rating': заполнена МОДОЙ 'TV-MA'
#   Причина: мода представляет наиболее типичную категорию
# Колонка 'duration': заполнена МОДОЙ '1 Season'
#   Причина: мода представляет наиболее типичную категорию
# C:\Users\Лена\AppData\Local\Temp\ipykernel_11876\1101036192.py:18: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include=['object']).columns
# C:\Users\Лена\AppData\Local\Temp\ipykernel_11876\1101036192.py:25: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df[col].fillna(mode_val, inplace=True)

# %%
print("Как считаем моду")

for col in cat_cols:
    if col in df.columns:  # проверяем, что колонка существует в исходных данных
        print(f"\nКолонка: {col}")
        # Вычисляем частоту встречаемости каждого значения
        value_counts = df[col].value_counts()
        print("Частота значений:")
        for val, count in value_counts.head().items():  # показываем топ-5
            print(f"  '{val}': {count} раз ({count/len(df)*100:.1f}%)")
        
        # Находим моду
        mode_val = df[col].mode()[0]
        mode_count = (df[col] == mode_val).sum()
        print(f"\nМОДА: '{mode_val}' (встречается {mode_count} раз)")
# Out:
# Как считаем моду
#
# Колонка: show_id
# Частота значений:
#   's1': 1 раз (0.0%)
#   's2': 1 раз (0.0%)
#   's3': 1 раз (0.0%)
#   's4': 1 раз (0.0%)
#   's5': 1 раз (0.0%)
#
# МОДА: 's1' (встречается 1 раз)
#
# Колонка: type
# Частота значений:
#   'Movie': 6131 раз (69.6%)
#   'TV Show': 2676 раз (30.4%)
#
# МОДА: 'Movie' (встречается 6131 раз)
#
# Колонка: title
# Частота значений:
#   'Dick Johnson Is Dead': 1 раз (0.0%)
#   'Blood & Water': 1 раз (0.0%)
#   'Ganglands': 1 раз (0.0%)
#   'Jailbirds New Orleans': 1 раз (0.0%)
#   'Kota Factory': 1 раз (0.0%)
#
# МОДА: '#Alive' (встречается 1 раз)
#
# Колонка: director
# Частота значений:
#   'Rajiv Chilaka': 19 раз (0.2%)
#   'Raúl Campos, Jan Suter': 18 раз (0.2%)
#   'Suhas Kadav': 16 раз (0.2%)
#   'Marcus Raboy': 16 раз (0.2%)
#   'Jay Karas': 14 раз (0.2%)
#
# МОДА: 'Rajiv Chilaka' (встречается 19 раз)
#
# Колонка: cast
# Частота значений:
#   'David Attenborough': 19 раз (0.2%)
#   'Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil': 14 раз (0.2%)
#   'Samuel West': 10 раз (0.1%)
#   'Jeff Dunham': 7 раз (0.1%)
#   'David Spade, London Hughes, Fortune Feimster': 6 раз (0.1%)
#
# МОДА: 'David Attenborough' (встречается 19 раз)
#
# Колонка: country
# Частота значений:
#   'United States': 2818 раз (32.0%)
#   'India': 972 раз (11.0%)
#   'United Kingdom': 419 раз (4.8%)
#   'Japan': 245 раз (2.8%)
#   'South Korea': 199 раз (2.3%)
#
# МОДА: 'United States' (встречается 2818 раз)
#
# Колонка: date_added
# Частота значений:
#   'January 1, 2020': 109 раз (1.2%)
#   'November 1, 2019': 89 раз (1.0%)
#   'March 1, 2018': 75 раз (0.9%)
#   'December 31, 2019': 74 раз (0.8%)
#   'October 1, 2018': 71 раз (0.8%)
#
# МОДА: 'January 1, 2020' (встречается 109 раз)
#
# Колонка: rating
# Частота значений:
#   'TV-MA': 3207 раз (36.4%)
#   'TV-14': 2160 раз (24.5%)
#   'TV-PG': 863 раз (9.8%)
#   'R': 799 раз (9.1%)
#   'PG-13': 490 раз (5.6%)
#
# МОДА: 'TV-MA' (встречается 3207 раз)
#
# Колонка: duration
# Частота значений:
#   '1 Season': 1793 раз (20.4%)
#   '2 Seasons': 425 раз (4.8%)
#   '3 Seasons': 199 раз (2.3%)
#   '90 min': 152 раз (1.7%)
#   '94 min': 146 раз (1.7%)
#
# МОДА: '1 Season' (встречается 1793 раз)
#
# Колонка: listed_in
# Частота значений:
#   'Dramas, International Movies': 362 раз (4.1%)
#   'Documentaries': 359 раз (4.1%)
#   'Stand-Up Comedy': 334 раз (3.8%)
#   'Comedies, Dramas, International Movies': 274 раз (3.1%)
#   'Dramas, Independent Movies, International Movies': 252 раз (2.9%)
#
# МОДА: 'Dramas, International Movies' (встречается 362 раз)
#
# Колонка: description
# Частота значений:
#   'Paranormal activity at a lush, abandoned property alarms a group eager to redevelop the site, but the eerie events may not be as unearthly as they think.': 4 раз (0.0%)
#   'Challenged to compose 100 songs before he can marry the girl he loves, a tortured but passionate singer-songwriter embarks on a poignant musical journey.': 3 раз (0.0%)
#   'Multiple women report their husbands as missing but when it appears they are looking for the same man, a police officer traces their cryptic connection.': 3 раз (0.0%)
#   'A surly septuagenarian gets another chance at her 20s after having her photo snapped at a studio that magically takes 50 years off her life.': 3 раз (0.0%)
#   'With their biggest foe seemingly defeated, InuYasha and his friends return to everyday life. But the peace is soon shattered by an emerging new enemy.': 2 раз (0.0%)
#
# МОДА: 'Paranormal activity at a lush, abandoned property alarms a group eager to redevelop the site, but the eerie events may not be as unearthly as they think.' (встречается 4 раз)

# %% [markdown]
# ЧАСТЬ С

# %%
#подсчет min, max, mean, median, mode для числовых колонок(только release_year)
for col in numeric_cols:
    print(f"Базовая статистика для {col}")
    print(f"Минимальное значение: {df['release_year'].min()}")
    print(f"Максимальное значение: {df['release_year'].max()}")
    print(f"Среднее значение: {df['release_year'].mean()}")
    print(f"Медиана: {df['release_year'].median()}")
    print(f"Мода: {df['release_year'].mode()[0]}")
# Out:
# Базовая статистика для release_year
# Минимальное значение: 1925
# Максимальное значение: 2021
# Среднее значение: 2014.1801975701146
# Медиана: 2017.0
# Мода: 2018

# %%
#перцентили
percentiles = [0.05, 0.25, 0.5, 0.75, 0.95]

for col in numeric_cols:
    print(f"Перцентили для {col}")
    for p in percentiles:
        value = df['release_year'].quantile(p)
        print(f"{p*100}: {value}")
# Out:
# Перцентили для release_year
# 5.0: 1997.0
# 25.0: 2013.0
# 50.0: 2017.0
# 75.0: 2019.0
# 95.0: 2021.0

# %%
#Продвинутая статистика

for col in numeric_cols:
    #varience - дисперсия показывает разброс данных вокруг среднего значения(типо ширина колокола)
    #в данном случае высокая дисперсия говорит о том, что на нетфликсе разброс даты выхода фильмов/сериалов большое,
    #т.е. много фильмов с разных времен
    varience = df[col].var()
    print(f"Varience: {varience:.2f}")

    #skewness - асимметрия показывает насколько график перекошен относительно среднего значения(форма колокола)
    # = 0 => симметрия
    # >0 => правостороняя(хвост справа, слева больше значений)
    # <0 => левосторонняя(хвост слева, справа больше значений)
    # Тут 'release_date' имеет левостороннюю асимметрию, т.е. на нетфликс постоянно добавляют новые фильмы/сериалы,
    # а старых фильмов меньше => хвост слева 
    skewness = df[col].skew()
    print(f"Skewness: {skewness:.2f}")

    #kurtosis - эксцесс показывает куда завален график(насколько острый пик, насколько тяжелые хвосты)
    # у нетфликса высокий положительный эксцесс, т.е. там большинство данных близки к среднему, но
    # часто встречаются и отклонения
    kurtosis = df[col].kurt()
    print(f"Kurtosis: {kurtosis:.2f}")
# Out:
# Varience: 77.78
# Skewness: -3.45
# Kurtosis: 16.23
